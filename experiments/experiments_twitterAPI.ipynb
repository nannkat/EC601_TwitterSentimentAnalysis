# %% [markdown]
# # Experiments with the twitter API
#
# With help from the following tutorial:
# https://towardsdatascience.com/an-extensive-guide-to-collecting-tweets-from-twitter-api-v2-for-academic-research-using-python-3-518fcb71df2a
#
# Along with the twitter documentation

# %% [markdown]
# ## Imports

# %%
import requests
import os
import datetime
import time
import dateutil.parser
import unicodedata
import json

# %% [markdown]
# ## Preparation of functions to use
# Initialize an environment variable for bearer token in a block that I delete so it is not pushed to git

# %%
def authorize():
    return os.environ['BEARER']

# %%
def create_headers(bearer_token):
    headers = {}
    headers["Authorization"] = "Bearer {}".format(bearer_token)
    return headers

# %%
def create_request(keyword, start_date, end_date, max_results = 10):
    pass

# %%
def connect_to_endpoint(url, headers, params = None):
    #params['next_token'] = next_token   #params object received from create_url function
    response = requests.request("GET", url, headers = headers, params = params)
    print("Endpoint Response Code: " + str(response.status_code))
    if response.status_code != 200:
        raise Exception(response.status_code, response.text)
    return response.json()

# %% [markdown]
# ## Initialize authorization token and header

# %%
bearer_token = authorize()
headers = create_headers(bearer_token)

# %% [markdown]
# ## Retrieve user data experiment
#
# Using the get user by username I found the id of my account and tried querying the tweets

# %%
url_name = "https://api.twitter.com/2/users/by/username/nannahann"
response = connect_to_endpoint(url_name, headers)
# Out:
# Endpoint Response Code: 200

# %%
print(response['data'])
# Out:
# {'id': '3126267033', 'name': 'Nanna', 'username': 'nannahann'}

# %%
print(json.dumps(response, indent=4, sort_keys=True))
nanna_id = response['data']['id']
print(nanna_id)
# Out:
# {
#     "data": {
#         "id": "3126267033",
#         "name": "Nanna",
#         "username": "nannahann"
#     }
# }
# 3126267033

# %%
url_name = "https://api.twitter.com/2/users/by/username/hsmarason"
response = connect_to_endpoint(url_name, headers)
hs_id = response['data']['id']
url_id = 'https://api.twitter.com/2/users/'+ hs_id +'/tweets'
parameters = {
    'tweet.fields': 'geo,created_at,public_metrics',
    'next_token': {}
}
response = connect_to_endpoint(url_id, headers, params = parameters)
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# Endpoint Response Code: 200
# Endpoint Response Code: 200
# {
#     "data": [
#         {
#             "created_at": "2021-09-11T13:50:47.000Z",
#             "id": "1436688675501481987",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 11547
#             },
#             "text": "RT @JoeBiden: Twenty years ago, nearly 3,000 lives were cut short by an unspeakable act of cowardice and hatred on 9/11. As a nation, we mu\u2026"
#         },
#         {
#             "created_at": "2021-09-11T13:49:16.000Z",
#             "id": "1436688292842463237",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 315
#             },
#             "text": "RT @EricTopol: 3 new @CDCMMWR reports today provide very strong reassurance of vaccination benefits vs Delta and point toward a potential e\u2026"
#         },
#         {
#             "created_at": "2021-09-10T13:54:28.000Z",
#             "id": "1436327214153359361",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 4
#             },
#             "text": "RT @rtnarch: Finally. Vaccine mandates. You still have a choice. Vaccinate or wear a mask and be tested all the time. Unless you are in hea\u2026"
#         },
#         {
#             "created_at": "2021-09-10T13:53:57.000Z",
#             "id": "1436327087028195329",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 6613
#             },
#             "text": "RT @moderna_tx: Today, we shared positive pre-clinical data demonstrating our ability to combine 6 mRNAs against 3 different respiratory vi\u2026"
#         },
#         {
#             "created_at": "2021-09-09T20:06:40.000Z",
#             "id": "1436058496496189447",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 49
#             },
#             "text": "RT @FinancialTimes: Breaking News: The Biden administration will demand that companies force their employees to get vaccinated against Covi\u2026"
#         },
#         {
#             "created_at": "2021-08-19T19:07:04.000Z",
#             "id": "1428433352533684230",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 39
#             },
#             "text": "RT @rtnarch: Congrats to Grail for its $10.9 billion acquisition by Illumina.  The first multi-cancer blood test, detecting up to 50 cancer\u2026"
#         },
#         {
#             "created_at": "2021-06-26T13:15:26.000Z",
#             "id": "1408775914406793226",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 31
#             },
#             "text": "RT @NatureBiotech: \u2018Super-antibodies\u2019 could curb COVID-19 and help avert future pandemics - @ElieDolgin https://t.co/vh0dtMsAIH https://t.c\u2026"
#         },
#         {
#             "created_at": "2021-06-16T12:52:00.000Z",
#             "id": "1405146137665888260",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "text": "Technology Saves the World https://t.co/MBaPG5HmeK"
#         },
#         {
#             "created_at": "2021-06-14T13:41:09.000Z",
#             "id": "1404433732656848898",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 8
#             },
#             "text": "RT @rtnarch: Congrats to Flagship on amazing fund expansion.  And thanks for Moderna from world.  :). https://t.co/t45ALxoyym"
#         },
#         {
#             "created_at": "2021-03-28T01:44:25.000Z",
#             "id": "1375987107521499136",
#             "public_metrics": {
#                 "like_count": 1,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "text": "Crazy pictures : Snj\u00f3rinn og hrauni\u00f0 myndu\u00f0u fallegan bakgrunn - https://t.co/TOW8c5UNEs https://t.co/BlCeduaDtU via @mblfrettir"
#         }
#     ],
#     "meta": {
#         "newest_id": "1436688675501481987",
#         "next_token": "7140dibdnow9c7btw3w3y5dkzqoq2li1y2ztzuggsuofq",
#         "oldest_id": "1375987107521499136",
#         "result_count": 10
#     }
# }

# %%
url_id = 'https://api.twitter.com/2/users/'+ nanna_id +'/tweets'
response = connect_to_endpoint(url_id, headers)
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# Endpoint Response Code: 200
# {
#     "data": [
#         {
#             "id": "956915469402951680",
#             "text": "RT @AldisMjoll: Settist \u00ed s\u00e6ti \u00ed @straetobs sem einhver annar hefur auglj\u00f3slega seti\u00f0 \u00ed lengi \u00e1 undan. Hl\u00fdtt og notalegt. \ud83d\ude0c\u2728 Hver \u00fearf rass\u2026"
#         },
#         {
#             "id": "944138060618399744",
#             "text": "@AldisMjoll H\u00e6ttu bara a\u00f0 kaupa \u00feessar n\u00fdjustu ger\u00f0ir alltaf hreint- gamla st\u00f6ffi\u00f0 klikkar ekki (kv \u00far fimmunni)"
#         },
#         {
#             "id": "943067713907380224",
#             "text": "P\u00e6ling; miki\u00f0 af sj\u00e1lfshj\u00e1lparb\u00f3kum til sem vilja kenna f\u00f3lki a\u00f0 fyrirgefa en hvar eru allar b\u00e6kurnar fyrir \u00fe\u00e1 sem \u00feurfa a\u00f0 l\u00e6ra a\u00f0 bi\u00f0jast fyrirgefningar? \ud83e\udd14"
#         },
#         {
#             "id": "942066590064967681",
#             "text": "@AldisMjoll sjitt tengi"
#         },
#         {
#             "id": "932398933153894400",
#             "text": "@AldisMjoll ok what var a\u00f0 fatta \u00fea\u00f0 n\u00fana a\u00f0 \u00feessi b\u00f3k h\u00e9ti \u00c1n tillits en ekki \u00c1n titils. Mind blown og \u00f6rl\u00edti\u00f0 sk\u00f6mmustuleg."
#         },
#         {
#             "id": "931451388986576896",
#             "text": "@AldisMjoll sk\u00e6r vonarstjarna innan netheimanna \ud83c\udf1f"
#         },
#         {
#             "id": "911735783777869824",
#             "text": "@unnspunns \u2764\ufe0f"
#         },
#         {
#             "id": "897960560750415872",
#             "text": "@emmaadolfs kasj\u00fa a\u00f0 utan, gull a\u00f0 innan?"
#         },
#         {
#             "id": "837238102536163328",
#             "text": "Ve\u00f0ri\u00f0 \u00feessa dagana \ud83d\ude0d\ud83d\ude0d"
#         }
#     ],
#     "meta": {
#         "newest_id": "956915469402951680",
#         "next_token": "zldjwdz3w6sba13nnr4j73j5hxbcvz4mvx5s4pejubc",
#         "oldest_id": "837238102536163328",
#         "result_count": 9
#     }
# }

# %% [markdown]
# ## Getting more fields and excluding retweets replys

# %%
#'query': '-is%3Aretweet%20-is%3Areply'
parameters = {
    'tweet.fields': 'geo,created_at,public_metrics',
    'next_token': {}
}
url_id = 'https://api.twitter.com/2/users/'+ nanna_id +'/tweets'
response = connect_to_endpoint(url_id, headers, params = parameters)
# Out:
# Endpoint Response Code: 200

# %%
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "data": [
#         {
#             "created_at": "2018-01-26T15:43:21.000Z",
#             "id": "956915469402951680",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 2
#             },
#             "text": "RT @AldisMjoll: Settist \u00ed s\u00e6ti \u00ed @straetobs sem einhver annar hefur auglj\u00f3slega seti\u00f0 \u00ed lengi \u00e1 undan. Hl\u00fdtt og notalegt. \ud83d\ude0c\u2728 Hver \u00fearf rass\u2026"
#         },
#         {
#             "created_at": "2017-12-22T09:30:29.000Z",
#             "id": "944138060618399744",
#             "public_metrics": {
#                 "like_count": 1,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 1
#             },
#             "text": "@AldisMjoll H\u00e6ttu bara a\u00f0 kaupa \u00feessar n\u00fdjustu ger\u00f0ir alltaf hreint- gamla st\u00f6ffi\u00f0 klikkar ekki (kv \u00far fimmunni)"
#         },
#         {
#             "created_at": "2017-12-19T10:37:19.000Z",
#             "id": "943067713907380224",
#             "public_metrics": {
#                 "like_count": 9,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "text": "P\u00e6ling; miki\u00f0 af sj\u00e1lfshj\u00e1lparb\u00f3kum til sem vilja kenna f\u00f3lki a\u00f0 fyrirgefa en hvar eru allar b\u00e6kurnar fyrir \u00fe\u00e1 sem \u00feurfa a\u00f0 l\u00e6ra a\u00f0 bi\u00f0jast fyrirgefningar? \ud83e\udd14"
#         },
#         {
#             "created_at": "2017-12-16T16:19:12.000Z",
#             "id": "942066590064967681",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "text": "@AldisMjoll sjitt tengi"
#         },
#         {
#             "created_at": "2017-11-20T00:03:23.000Z",
#             "id": "932398933153894400",
#             "public_metrics": {
#                 "like_count": 3,
#                 "quote_count": 0,
#                 "reply_count": 1,
#                 "retweet_count": 1
#             },
#             "text": "@AldisMjoll ok what var a\u00f0 fatta \u00fea\u00f0 n\u00fana a\u00f0 \u00feessi b\u00f3k h\u00e9ti \u00c1n tillits en ekki \u00c1n titils. Mind blown og \u00f6rl\u00edti\u00f0 sk\u00f6mmustuleg."
#         },
#         {
#             "created_at": "2017-11-17T09:18:11.000Z",
#             "id": "931451388986576896",
#             "public_metrics": {
#                 "like_count": 1,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 1
#             },
#             "text": "@AldisMjoll sk\u00e6r vonarstjarna innan netheimanna \ud83c\udf1f"
#         },
#         {
#             "created_at": "2017-09-23T23:35:24.000Z",
#             "id": "911735783777869824",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "text": "@unnspunns \u2764\ufe0f"
#         },
#         {
#             "created_at": "2017-08-16T23:17:35.000Z",
#             "id": "897960560750415872",
#             "public_metrics": {
#                 "like_count": 1,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "text": "@emmaadolfs kasj\u00fa a\u00f0 utan, gull a\u00f0 innan?"
#         },
#         {
#             "created_at": "2017-03-02T09:48:13.000Z",
#             "id": "837238102536163328",
#             "public_metrics": {
#                 "like_count": 3,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "text": "Ve\u00f0ri\u00f0 \u00feessa dagana \ud83d\ude0d\ud83d\ude0d"
#         }
#     ],
#     "meta": {
#         "newest_id": "956915469402951680",
#         "next_token": "zldjwdz3w6sba13nnr4j73j5hxbcvz4mvx5s4pejubc",
#         "oldest_id": "837238102536163328",
#         "result_count": 9
#     }
# }

# %%
print(response['data'][-1])
print()
print(response['meta'])
# Out:
# {'public_metrics': {'retweet_count': 0, 'reply_count': 0, 'like_count': 3, 'quote_count': 0}, 'created_at': '2017-03-02T09:48:13.000Z', 'text': 'Veðrið þessa dagana 😍😍', 'id': '837238102536163328'}
#
# {'oldest_id': '837238102536163328', 'newest_id': '956915469402951680', 'result_count': 9, 'next_token': 'zldjwdz3w6sba13nnr4j73j5hxbcvz4mvx5s4pejubc'}

# %% [markdown]
# See that the oldest tweet is from 2017, try getting more with next_token:

# %%
parameters['next_token'] = response['meta']['next_token']
response = connect_to_endpoint(url_id, headers, params = parameters)
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# Endpoint Response Code: 400
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-49-8c9964933aa5> in <module>
#       1 parameters['next_token'] = response['meta']['next_token'][0]
# ----> 2 response = connect_to_endpoint(url_id, headers, params = parameters)
#       3 print(json.dumps(response, indent=4, sort_keys=True))
#
# <ipython-input-39-5bced928fa67> in connect_to_endpoint(url, headers, params)
#       4     print("Endpoint Response Code: " + str(response.status_code))
#       5     if response.status_code != 200:
# ----> 6         raise Exception(response.status_code, response.text)
#       7     return response.json()
#
# Exception: (400, '{"errors":[{"parameters":{"next_token":["z"]},"message":"The query parameter [next_token] is not one of [id,since_id,until_id,max_results,pagination_token,exclude,start_time,end_time,expansions,tweet.fields,media.fields,poll.fields,place.fields,user.fields]"}],"title":"Invalid Request","detail":"One or more parameters to your request was invalid.","type":"https://api.twitter.com/2/problems/invalid-request"}')

# %% [markdown]
# Does not work, try changing parameters and using: start time, end time

# %%
start_date = '2015-09-15T02:53:59.00Z'
end_date = '2016-12-31T02:53:59.00Z'
parameters = {
    'start_time': start_date,
    'end_time': end_date,
    'tweet.fields': 'created_at,public_metrics',
    'next_token': {}
}
response = connect_to_endpoint(url_id, headers, params = parameters)
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# Endpoint Response Code: 200
# {
#     "data": [
#         {
#             "created_at": "2016-12-29T18:03:54.000Z",
#             "id": "814532408011800576",
#             "public_metrics": {
#                 "like_count": 2,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "text": "Loksins farin a\u00f0 s\u00fdna mitt r\u00e9tta andlit https://t.co/Ojn5Autkdl"
#         },
#         {
#             "created_at": "2016-12-19T16:24:31.000Z",
#             "id": "810883518939230208",
#             "public_metrics": {
#                 "like_count": 1,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "text": "\u00dej\u00e1ist af ofn\u00e6mi (\u00fe.e. er of-n\u00e6m)"
#         },
#         {
#             "created_at": "2016-12-12T16:32:36.000Z",
#             "id": "808348839937798144",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "text": "\ud83d\ude4f\ud83c\udffb\ud83d\ude0d https://t.co/ckZVZAQKlS"
#         },
#         {
#             "created_at": "2016-12-10T18:27:41.000Z",
#             "id": "807653027503083520",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "text": "@AldisMjoll \"Catch Him and keep Him\""
#         },
#         {
#             "created_at": "2016-12-08T19:47:59.000Z",
#             "id": "806948457072181248",
#             "public_metrics": {
#                 "like_count": 1,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "text": "@alexandravanerv what a man \ud83d\ude0d\ud83d\ude0d"
#         },
#         {
#             "created_at": "2016-11-24T11:02:50.000Z",
#             "id": "801742870101315584",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "text": "@TUSS4N h\u00e6ttir samt ekki a\u00f0 vera tussa \u00fer\u00e1tt fyrir \u00fea\u00f0 \ud83e\udd17"
#         },
#         {
#             "created_at": "2016-11-16T14:13:08.000Z",
#             "id": "798891658163040257",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "text": "@TUSS4N bara einn fokking regla..."
#         },
#         {
#             "created_at": "2016-11-14T15:45:22.000Z",
#             "id": "798190091399294981",
#             "public_metrics": {
#                 "like_count": 4,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "text": "@TUSS4N @erlaylfa  og @tryggviskarp  eru n\u00e1ttla h\u00f6mlulaus \u00ed tr\u00edtinu...."
#         }
#     ],
#     "meta": {
#         "newest_id": "814532408011800576",
#         "next_token": "zldjwdz3w6sba13nktvmxzl89uyv4nyqtg650rytwkx",
#         "oldest_id": "798190091399294981",
#         "result_count": 8
#     }
# }

# %% [markdown]
# Or, change result count number! (max is 100 but default only 10). For fun add an expansion of media keys, in case there was a photo or video attached.

# %%
max_results = 50
parameters = {
    'start_time': {},
    'end_time': {},
    'max_results' : max_results,
    'expansions' : 'attachments.media_keys',
    'tweet.fields': 'created_at,public_metrics',
    'next_token': {}
}
response = connect_to_endpoint(url_id, headers, params = parameters)
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# Endpoint Response Code: 200
# {
#     "data": [
#         {
#             "created_at": "2018-01-26T15:43:21.000Z",
#             "id": "956915469402951680",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 2
#             },
#             "text": "RT @AldisMjoll: Settist \u00ed s\u00e6ti \u00ed @straetobs sem einhver annar hefur auglj\u00f3slega seti\u00f0 \u00ed lengi \u00e1 undan. Hl\u00fdtt og notalegt. \ud83d\ude0c\u2728 Hver \u00fearf rass\u2026"
#         },
#         {
#             "created_at": "2017-12-22T09:30:29.000Z",
#             "id": "944138060618399744",
#             "public_metrics": {
#                 "like_count": 1,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 1
#             },
#             "text": "@AldisMjoll H\u00e6ttu bara a\u00f0 kaupa \u00feessar n\u00fdjustu ger\u00f0ir alltaf hreint- gamla st\u00f6ffi\u00f0 klikkar ekki (kv \u00far fimmunni)"
#         },
#         {
#             "created_at": "2017-12-19T10:37:19.000Z",
#             "id": "943067713907380224",
#             "public_metrics": {
#                 "like_count": 9,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "text": "P\u00e6ling; miki\u00f0 af sj\u00e1lfshj\u00e1lparb\u00f3kum til sem vilja kenna f\u00f3lki a\u00f0 fyrirgefa en hvar eru allar b\u00e6kurnar fyrir \u00fe\u00e1 sem \u00feurfa a\u00f0 l\u00e6ra a\u00f0 bi\u00f0jast fyrirgefningar? \ud83e\udd14"
#         },
#         {
#             "created_at": "2017-12-16T16:19:12.000Z",
#             "id": "942066590064967681",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "text": "@AldisMjoll sjitt tengi"
#         },
#         {
#             "created_at": "2017-11-20T00:03:23.000Z",
#             "id": "932398933153894400",
#             "public_metrics": {
#                 "like_count": 3,
#                 "quote_count": 0,
#                 "reply_count": 1,
#                 "retweet_count": 1
#             },
#             "text": "@AldisMjoll ok what var a\u00f0 fatta \u00fea\u00f0 n\u00fana a\u00f0 \u00feessi b\u00f3k h\u00e9ti \u00c1n tillits en ekki \u00c1n titils. Mind blown og \u00f6rl\u00edti\u00f0 sk\u00f6mmustuleg."
#         },
#         {
#             "created_at": "2017-11-17T09:18:11.000Z",
#             "id": "931451388986576896",
#             "public_metrics": {
#                 "like_count": 1,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 1
#             },
#             "text": "@AldisMjoll sk\u00e6r vonarstjarna innan netheimanna \ud83c\udf1f"
#         },
#         {
#             "created_at": "2017-09-23T23:35:24.000Z",
#             "id": "911735783777869824",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "text": "@unnspunns \u2764\ufe0f"
#         },
#         {
#             "created_at": "2017-08-16T23:17:35.000Z",
#             "id": "897960560750415872",
#             "public_metrics": {
#                 "like_count": 1,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "text": "@emmaadolfs kasj\u00fa a\u00f0 utan, gull a\u00f0 innan?"
#         },
#         {
#             "created_at": "2017-03-02T09:48:13.000Z",
#             "id": "837238102536163328",
#             "public_metrics": {
#                 "like_count": 3,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "text": "Ve\u00f0ri\u00f0 \u00feessa dagana \ud83d\ude0d\ud83d\ude0d"
#         },
#         {
#             "created_at": "2017-02-19T21:47:12.000Z",
#             "id": "833432774266802179",
#             "public_metrics": {
#                 "like_count": 1,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "text": "@AldisMjoll \u00f3gleymanlegt. Svo var \u00fea\u00f0 minningagreinin g\u00f3\u00f0a- hvar er ekki til ofl...."
#         },
#         {
#             "created_at": "2017-02-19T18:54:17.000Z",
#             "id": "833389260250165248",
#             "public_metrics": {
#                 "like_count": 1,
#                 "quote_count": 0,
#                 "reply_count": 1,
#                 "retweet_count": 0
#             },
#             "text": "@AldisMjoll RIP B1a \ud83d\ude22"
#         },
#         {
#             "created_at": "2017-01-06T14:57:15.000Z",
#             "id": "817384539546939392",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 1
#             },
#             "text": "RT @emmaadolfs: A\u00f0 vaska upp er huglei\u00f0sla"
#         },
#         {
#             "created_at": "2017-01-04T13:45:00.000Z",
#             "id": "816641580983615488",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 6823
#             },
#             "text": "RT @officialjaden: Soul Searching"
#         },
#         {
#             "attachments": {
#                 "media_keys": [
#                     "3_814532397983219713"
#                 ]
#             },
#             "created_at": "2016-12-29T18:03:54.000Z",
#             "id": "814532408011800576",
#             "public_metrics": {
#                 "like_count": 2,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "text": "Loksins farin a\u00f0 s\u00fdna mitt r\u00e9tta andlit https://t.co/Ojn5Autkdl"
#         },
#         {
#             "created_at": "2016-12-19T16:24:31.000Z",
#             "id": "810883518939230208",
#             "public_metrics": {
#                 "like_count": 1,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "text": "\u00dej\u00e1ist af ofn\u00e6mi (\u00fe.e. er of-n\u00e6m)"
#         },
#         {
#             "created_at": "2016-12-12T16:32:36.000Z",
#             "id": "808348839937798144",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "text": "\ud83d\ude4f\ud83c\udffb\ud83d\ude0d https://t.co/ckZVZAQKlS"
#         },
#         {
#             "created_at": "2016-12-10T18:27:41.000Z",
#             "id": "807653027503083520",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "text": "@AldisMjoll \"Catch Him and keep Him\""
#         },
#         {
#             "created_at": "2016-12-08T19:47:59.000Z",
#             "id": "806948457072181248",
#             "public_metrics": {
#                 "like_count": 1,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "text": "@alexandravanerv what a man \ud83d\ude0d\ud83d\ude0d"
#         },
#         {
#             "created_at": "2016-11-24T11:02:50.000Z",
#             "id": "801742870101315584",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "text": "@TUSS4N h\u00e6ttir samt ekki a\u00f0 vera tussa \u00fer\u00e1tt fyrir \u00fea\u00f0 \ud83e\udd17"
#         },
#         {
#             "created_at": "2016-11-16T14:13:08.000Z",
#             "id": "798891658163040257",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "text": "@TUSS4N bara einn fokking regla..."
#         },
#         {
#             "created_at": "2016-11-14T15:45:22.000Z",
#             "id": "798190091399294981",
#             "public_metrics": {
#                 "like_count": 4,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "text": "@TUSS4N @erlaylfa  og @tryggviskarp  eru n\u00e1ttla h\u00f6mlulaus \u00ed tr\u00edtinu...."
#         },
#         {
#             "created_at": "2016-11-08T14:13:15.000Z",
#             "id": "795992584967585793",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "text": "@throtbjorn \ud83d\ude4f\ud83c\udffb\ud83d\ude4f\ud83c\udffb\ud83d\ude4f\ud83c\udffb"
#         },
#         {
#             "created_at": "2016-11-07T22:42:31.000Z",
#             "id": "795758358649335808",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 1,
#                 "retweet_count": 0
#             },
#             "text": "@throtbjorn langar \u00ed \ud83c\udf6d\ud83d\ude07"
#         },
#         {
#             "created_at": "2016-11-06T15:39:22.000Z",
#             "id": "795289479581929472",
#             "public_metrics": {
#                 "like_count": 4,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "text": "\u00dea\u00f0 er eitthva\u00f0 verulega \u00f3\u00fe\u00e6gilegt vi\u00f0 \u00fea\u00f0 \u00feegar f\u00f3lk er me\u00f0 vekjarat\u00f3ninn manns sem hringit\u00f3n"
#         },
#         {
#             "created_at": "2016-11-05T13:53:59.000Z",
#             "id": "794900573048995840",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 8
#             },
#             "text": "RT @toppsjomli: Landaboi$ - Vodafone H\u00f6llin, uppi - kl 2:20 \u00ed kv\u00f6ld"
#         },
#         {
#             "created_at": "2016-10-31T22:52:11.000Z",
#             "id": "793224073543385088",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 1
#             },
#             "text": "RT @AldisMjoll: SJIITTTT hva\u00f0 \u00fea\u00f0 er mikill m\u00e1nudagur"
#         },
#         {
#             "created_at": "2016-10-30T22:45:37.000Z",
#             "id": "792860034749390848",
#             "public_metrics": {
#                 "like_count": 1,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "text": "@emmaadolfs lifir n\u00e1ttla \u00e1 br\u00faninni"
#         },
#         {
#             "created_at": "2016-10-22T23:57:41.000Z",
#             "id": "789979065721683969",
#             "public_metrics": {
#                 "like_count": 1,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "text": "@AldisMjoll metna\u00f0ur er sex\u00fd \ud83d\ude0d"
#         },
#         {
#             "created_at": "2016-10-22T22:16:25.000Z",
#             "id": "789953584385458176",
#             "public_metrics": {
#                 "like_count": 1,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "text": "@tunglbjort \ud83d\ude41"
#         },
#         {
#             "created_at": "2016-10-20T22:16:55.000Z",
#             "id": "789228931761246209",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "text": "@AldisMjoll \u00feau gera \u00feetta eflaust bara \u00feegar \u00feau eru me\u00f0 snappi\u00f0 ;)"
#         },
#         {
#             "created_at": "2016-10-18T20:26:23.000Z",
#             "id": "788476340886507520",
#             "public_metrics": {
#                 "like_count": 1,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "text": "\u00dea\u00f0 getur veri\u00f0 t\u00e1kn um a\u00f0 s\u00e1lgreiningin s\u00e9 \u00e1 r\u00e9ttri lei\u00f0 ef sj\u00faklingurinn andm\u00e6lir af alefli og kemst \u00ed mikla ge\u00f0shr\u00e6ringu."
#         },
#         {
#             "created_at": "2016-10-12T22:55:16.000Z",
#             "id": "786339479577657345",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 6
#             },
#             "text": "RT @oratorhi: It's on. @TUSS4N keppir \u00e1 f\u00f6studag. Ekkert bull. RT ef \u00fe\u00fa heldur a\u00f0 Hanna sigri \u00feetta. #oratorum16 https://t.co/hPSjCFX5Bm"
#         },
#         {
#             "attachments": {
#                 "media_keys": [
#                     "3_782615272561709057"
#                 ]
#             },
#             "created_at": "2016-10-02T16:16:40.000Z",
#             "id": "782615289913573377",
#             "public_metrics": {
#                 "like_count": 2,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "text": "#allmenmustdine https://t.co/vsL5yB9AuT"
#         },
#         {
#             "created_at": "2016-10-01T22:42:56.000Z",
#             "id": "782350112387371009",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "text": "@AldisMjoll enda l\u00fasam\u00f3\u00f0ir!"
#         },
#         {
#             "created_at": "2016-09-26T15:58:38.000Z",
#             "id": "780436427842658304",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "text": "@TUSS4N lorta\u00f0 \ud83d\ude05"
#         },
#         {
#             "created_at": "2016-09-08T18:04:40.000Z",
#             "id": "773945160078163969",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "text": "Er b\u00fain a\u00f0 hugsa svo miki\u00f0 \u00ed dag a\u00f0 \u00e9g er komin me\u00f0 hausverk #livet ma\u00f0\u00f6\u00f6r"
#         },
#         {
#             "attachments": {
#                 "media_keys": [
#                     "3_773891147810897920"
#                 ]
#             },
#             "created_at": "2016-09-08T14:30:06.000Z",
#             "id": "773891163292073984",
#             "public_metrics": {
#                 "like_count": 3,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "text": "\u00deessi er spennt fyrir Bieber \u00ed kv\u00f6ld https://t.co/YwqcQ1RzSL"
#         },
#         {
#             "created_at": "2016-09-07T17:35:24.000Z",
#             "id": "773575408491126784",
#             "public_metrics": {
#                 "like_count": 1,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "text": "@AldisMjoll \ud83d\ude41 hvers \u00e1 andans f\u00f3lk a\u00f0 gjalda \ud83d\ude14"
#         },
#         {
#             "created_at": "2016-09-06T14:16:23.000Z",
#             "id": "773162937854861313",
#             "public_metrics": {
#                 "like_count": 1,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "text": "@AldisMjoll S\u00c1\u00c1 l\u00edfsst\u00edllinn: \u00e1netjast spilak\u00f6ssum (\u00ed bo\u00f0i s\u00e1\u00e1)-&gt;f\u00e1 hj\u00e1lp (fr\u00e1 s\u00e1\u00e1)-&gt;byrja aftur a\u00f0 spila (#takks\u00e1\u00e1)-&gt;......"
#         },
#         {
#             "created_at": "2016-09-04T16:45:03.000Z",
#             "id": "772475573822189569",
#             "public_metrics": {
#                 "like_count": 4,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "text": "@AldisMjoll @tunglbjort minna er ekki sama og l\u00edti\u00f0 \ud83d\ude09\ud83d\ude09\ud83d\ude09"
#         },
#         {
#             "created_at": "2016-09-04T14:52:03.000Z",
#             "id": "772447135891587073",
#             "public_metrics": {
#                 "like_count": 6,
#                 "quote_count": 0,
#                 "reply_count": 1,
#                 "retweet_count": 0
#             },
#             "text": "Er strax byrju\u00f0 a\u00f0 gr\u00e6\u00f0a \u00e1 \"drekka minna djamma oftar\" l\u00edfsst\u00edlnum: eyddi samtals 2300kr \u00e1 barnum um helgina og man e \u00f6llu. M\u00e6li me\u00f0 \ud83d\udc4d\ud83c\udffb\ud83d\udc4d\ud83c\udffb"
#         },
#         {
#             "created_at": "2016-08-30T14:15:46.000Z",
#             "id": "770626066402701313",
#             "public_metrics": {
#                 "like_count": 1,
#                 "quote_count": 0,
#                 "reply_count": 1,
#                 "retweet_count": 0
#             },
#             "text": "@TUSS4N hahaha; er veri\u00f0 a\u00f0 koma r\u00fat\u00ednu \u00e1 livet? Sm\u00e1 life coach? A\u00f0v\u00f6run: eg hata life coach p\u00e6linguna"
#         },
#         {
#             "created_at": "2016-08-29T11:18:16.000Z",
#             "id": "770219008960454656",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 1
#             },
#             "text": "RT @AldisMjoll: \u00d3, elsku H\u00e1mukaffi, \u00fea\u00f0 sem \u00e9g hef sakna\u00f0 \u00fe\u00edn! \ud83d\ude0c\u2615\ufe0f\ud83d\udc95"
#         },
#         {
#             "attachments": {
#                 "media_keys": [
#                     "3_769841793437429760"
#                 ]
#             },
#             "created_at": "2016-08-28T10:19:24.000Z",
#             "id": "769841805412143104",
#             "public_metrics": {
#                 "like_count": 1,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "text": "@tunglbjort munum nattla hvernig \u00feetta byrja\u00f0i... https://t.co/yynnNfpoef"
#         },
#         {
#             "attachments": {
#                 "media_keys": [
#                     "3_769608004064935936"
#                 ]
#             },
#             "created_at": "2016-08-27T18:50:25.000Z",
#             "id": "769608022129774592",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "text": "Hin heilaga tvenna \ud83d\ude4f\ud83c\udffb https://t.co/fu9P2ralHI"
#         },
#         {
#             "created_at": "2016-08-16T16:52:03.000Z",
#             "id": "765591968000962561",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "text": "@TUSS4N @tunglbjort skal borga meira en Hanna OG gefa \u00feer nudd"
#         }
#     ],
#     "includes": {
#         "media": [
#             {
#                 "media_key": "3_814532397983219713",
#                 "type": "photo"
#             },
#             {
#                 "media_key": "3_782615272561709057",
#                 "type": "photo"
#             },
#             {
#                 "media_key": "3_773891147810897920",
#                 "type": "photo"
#             },
#             {
#                 "media_key": "3_769841793437429760",
#                 "type": "photo"
#             },
#             {
#                 "media_key": "3_769608004064935936",
#                 "type": "photo"
#             }
#         ]
#     },
#     "meta": {
#         "newest_id": "956915469402951680",
#         "next_token": "zldjwdz3w6sba13nkslzr6js42tlazavnvj0cl1y8tt",
#         "oldest_id": "765591968000962561",
#         "result_count": 46
#     }
# }

# %%
print(json.dumps(response['data'][-3:-1], indent=4, sort_keys=True))
# Out:
# [
#     {
#         "attachments": {
#             "media_keys": [
#                 "3_769841793437429760"
#             ]
#         },
#         "created_at": "2016-08-28T10:19:24.000Z",
#         "id": "769841805412143104",
#         "public_metrics": {
#             "like_count": 1,
#             "quote_count": 0,
#             "reply_count": 0,
#             "retweet_count": 0
#         },
#         "text": "@tunglbjort munum nattla hvernig \u00feetta byrja\u00f0i... https://t.co/yynnNfpoef"
#     },
#     {
#         "attachments": {
#             "media_keys": [
#                 "3_769608004064935936"
#             ]
#         },
#         "created_at": "2016-08-27T18:50:25.000Z",
#         "id": "769608022129774592",
#         "public_metrics": {
#             "like_count": 0,
#             "quote_count": 0,
#             "reply_count": 0,
#             "retweet_count": 0
#         },
#         "text": "Hin heilaga tvenna \ud83d\ude4f\ud83c\udffb https://t.co/fu9P2ralHI"
#     }
# ]

# %% [markdown]
# Now we see media keys added and are getting older tweets

# %% [markdown]
# ## Retrieving tweets based on query
#
# There are elections in Iceland tonight. Let's see if I can query for some tweets on it. The Icelandic word for elections is 'kosningar'.
# Start by defining some variables, modifying parameters and adding a query:

# %%
url_search = 'https://api.twitter.com/2/tweets/search/recent?query=kosning%20-is%3Aretweet%20-is%3Areply'
max_results = 10
parameters = {
    'start_time': {},
    'end_time': {},
    'max_results' : max_results,
    'expansions' : {},
    'tweet.fields': 'created_at,public_metrics',
    'next_token': {}
}

response = connect_to_endpoint(url_search, headers, params = parameters)
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# Endpoint Response Code: 200
# {
#     "data": [
#         {
#             "created_at": "2021-09-26T03:09:34.000Z",
#             "id": "1441963125746634756",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "text": "Gr\u00e9tar \u00de\u00f3r Ey\u00fe\u00f3rsson pr\u00f3fessor \u00ed stj\u00f3rnm\u00e1lafr\u00e6\u00f0i segir lj\u00f3st a\u00f0 r\u00edkisstj\u00f3rnarflokkarnir hafi n\u00e1\u00f0 vopnum s\u00ednum aftur \u00e1 lokasprettinum en \u00fea\u00f0 s\u00e9 \u00fe\u00f3 ekki \u00e1fellisd\u00f3mur yfir k\u00f6nnunum sem sl\u00edkum. Marka\u00f0sherfer\u00f0ir flokkanna hafi greinilega falli\u00f0 misvel \u00ed ... https://t.co/ZuuqOPUHIz https://t.co/tTcKW03vxA"
#         },
#         {
#             "created_at": "2021-09-26T01:46:39.000Z",
#             "id": "1441942262041169921",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "text": "Svand\u00eds kve\u00f0st gl\u00f6\u00f0 me\u00f0 a\u00f0 hafa \u00feingmann me\u00f0 s\u00e9r \u00ed kj\u00f6rd\u00e6minu mi\u00f0a\u00f0 vi\u00f0 fyrstu t\u00f6lur og \u00feakkar m\u00e1lefnalegri bar\u00e1ttu s\u00edns f\u00f3lks sveifluna sem vir\u00f0ist vera n\u00fa me\u00f0 Vinstri hreyfingunni gr\u00e6nu frambo\u00f0i. https://t.co/h3mLA1goGX https://t.co/do2HMBGEjo"
#         },
#         {
#             "created_at": "2021-09-26T01:32:05.000Z",
#             "id": "1441938595086995457",
#             "public_metrics": {
#                 "like_count": 1,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "text": "Eva Hei\u00f0a \u00d6nnud\u00f3ttir stj\u00f3rnm\u00e1lafr\u00e6\u00f0ingur segir fyrstu t\u00f6lur kosninganna um margt athyglisver\u00f0ar \u00fe\u00f3 \u00fe\u00e6r eigi ekki a\u00f0 koma neinum kunnugum p\u00f3lit\u00edk \u00e1 \u00f3vart. H\u00fan segir minna fylgi Vinstri gr\u00e6nna geti neytt \u00feau til \u00feess a\u00f0 endurmeta st\u00f6\u00f0u s\u00edna sem kunni a\u00f0 ... https://t.co/4JZNDRPIVP https://t.co/fy95XwlW4x"
#         },
#         {
#             "created_at": "2021-09-26T01:15:08.000Z",
#             "id": "1441934330687754241",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "text": "R\u00edkisstj\u00f3rnin heldur velli eftir fyrstu t\u00f6lur - https://t.co/QauQigBmif"
#         },
#         {
#             "created_at": "2021-09-26T01:03:41.000Z",
#             "id": "1441931446764113923",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "text": "St\u00e6r\u00f0arinnar r\u00f6\u00f0 mynda\u00f0ist vi\u00f0 inngang veislusals H\u00f3tel Nordica \u00fear sem kosningavaka Sj\u00e1lfst\u00e6\u00f0isflokks fer fram. https://t.co/OAfpXgU8D3 https://t.co/AsVMWNMkKt"
#         },
#         {
#             "created_at": "2021-09-26T00:17:57.000Z",
#             "id": "1441919939216953345",
#             "public_metrics": {
#                 "like_count": 1,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "text": "\u201e\u00dea\u00f0 \u00fearf ekki a\u00f0 spyrja a\u00f0 \u00fev\u00ed hvar besta part\u00fdi\u00f0 er \u00fev\u00ed a\u00f0 \u00fea\u00f0 er svo auglj\u00f3st a\u00f0 \u00fea\u00f0 er n\u00e1kv\u00e6mlega h\u00e9r og \u00fea\u00f0 er n\u00e1kv\u00e6mlega n\u00fana,\u201c sag\u00f0i Katr\u00edn Jakobsd\u00f3ttir fors\u00e6tisr\u00e1\u00f0herra vi\u00f0 mikil fagna\u00f0arl\u00e6ti \u00feegar h\u00fan \u00e1varpa\u00f0i f\u00e9laga s\u00edna \u00ed Vinstri hreyfingunni... https://t.co/z9nc5WgAIX https://t.co/OgnbX5sGxD"
#         },
#         {
#             "created_at": "2021-09-26T00:00:30.000Z",
#             "id": "1441915548296695808",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "text": "Bjarni Benediktsson, forma\u00f0ur Sj\u00e1lfst\u00e6\u00f0isflokksins, segir fyrstu t\u00f6lur \u00far Su\u00f0ur- og Nor\u00f0vesturkj\u00f6rd\u00e6mi endurspegla \u00e1g\u00e6tlega \u00fea\u00f0 sem hann bj\u00f3st vi\u00f0 \u00fer\u00e1tt fyrir slaka m\u00e6lingu \u00ed sko\u00f0anak\u00f6nnunum s\u00ed\u00f0ustu daga kosningabar\u00e1ttunnar. https://t.co/lbRdMXDMKy https://t.co/eCngn8d3RM"
#         },
#         {
#             "created_at": "2021-09-25T23:48:29.000Z",
#             "id": "1441912521867370500",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "text": "Mikill f\u00f6gnu\u00f0ur braust \u00fat \u00e1 kosningav\u00f6ku Frams\u00f3knarflokksins \u00feegar fyrstu t\u00f6lur \u00far Su\u00f0ur- og Nor\u00f0vesturkj\u00f6rd\u00e6mi komu inn. https://t.co/RefYotZ6PB https://t.co/W5xvmWTPc5"
#         },
#         {
#             "created_at": "2021-09-25T23:22:25.000Z",
#             "id": "1441905961292255232",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "text": "\u201e\u00c9g var n\u00fa a\u00f0 gera gr\u00edn a\u00f0 \u00fev\u00ed a\u00f0 \u00e9g \u00feyrfti a\u00f0 taka me\u00f0 m\u00e9r s\u00f3lgleraugu, v\u00e6ri or\u00f0inn of bjarts\u00fdnn. \u00c9g hef\u00f0i sennilega \u00e1tt a\u00f0 gera \u00fea\u00f0,\u201c sag\u00f0i Gu\u00f0mundur Ingi Kristinsson, \u00feingma\u00f0ur Flokks f\u00f3lksins, \u00feegar bla\u00f0ama\u00f0ur https://t.co/J3OM7eo4id n\u00e1\u00f0i af honum tali sk\u00f6mmu eftir a\u00f0 ... https://t.co/HSnbNXCMKU"
#         },
#         {
#             "created_at": "2021-09-25T22:51:39.000Z",
#             "id": "1441898218753826820",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "text": "Nokkrir \u00feingflokksformenn vir\u00f0ast hafa virt 117. grein kosningalaga a\u00f0 vettugi \u00feegar \u00feeir gengu til kosninga i dag. \u00cd greininni er \u00fea\u00f0 kalla\u00f0 \u00f3leyfilegur kosninga\u00e1r\u00f3\u00f0ur og kosningaspj\u00f6ll \u201ea\u00f0 reyna a\u00f0 hafa \u00e1hrif \u00e1 atkv\u00e6\u00f0agrei\u00f0slu, [...], me\u00f0 \u00fev\u00ed a\u00f0 bera ... https://t.co/b1Vi0zHYlz https://t.co/9fTq3GfKzA"
#         }
#     ],
#     "meta": {
#         "newest_id": "1441963125746634756",
#         "next_token": "b26v89c19zqg8o3fpds6g0lm3rkqhc6ay1rfv4vec3ud9",
#         "oldest_id": "1441898218753826820",
#         "result_count": 10
#     }
# }

# %% [markdown]
# Indeed, results from the elections are queried after looking through them and looking past the fact that you have all the misisng letters where Icelandic alphabet takes over.

# %% [markdown]
# ## Another query with more conditions
#
# Let's try filtering tweets on pets (cats&dogs) from the last hour that include images.

# %%
url_search = 'https://api.twitter.com/2/tweets/search/recent?query=(cat%20OR%20dog)%20has%3Aimages%20-is%3Aretweet'
max_results = 10
parameters = {
    'start_time': '2021-09-25T22:30:59.00Z',
    'end_time': '2021-09-25T23:30:59.00Z',
    'max_results' : max_results,
    'expansions' : {},
    'tweet.fields': 'created_at,public_metrics',
    'next_token': {}
}

response = connect_to_endpoint(url_search, headers, params = parameters)
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# Endpoint Response Code: 200
# {
#     "data": [
#         {
#             "created_at": "2021-09-25T23:30:57.000Z",
#             "id": "1441908109593567232",
#             "public_metrics": {
#                 "like_count": 2,
#                 "quote_count": 0,
#                 "reply_count": 1,
#                 "retweet_count": 0
#             },
#             "text": "@weareronin47 @_dog_soldier_ https://t.co/GajpgZ1mry"
#         },
#         {
#             "created_at": "2021-09-25T23:30:56.000Z",
#             "id": "1441908105906900996",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "text": "@el_yuuri Minha madrugada vai ser triste,mais eu te entendo bom descanso dog\u270c\u2764 https://t.co/f9c3CPD9Zw"
#         },
#         {
#             "created_at": "2021-09-25T23:30:56.000Z",
#             "id": "1441908105261027329",
#             "public_metrics": {
#                 "like_count": 75,
#                 "quote_count": 1,
#                 "reply_count": 75,
#                 "retweet_count": 74
#             },
#             "text": "\ud83c\udf81Cool Cat giveaway\ud83c\udf81\n\nRules to get rich:\n1\ufe0f\u20e3 Follow Me / \ud83d\udd14\n2\ufe0f\u20e3 Like &amp; RT \u2764\n3\ufe0f\u20e3 Tag more Friends more chances to win \ud83e\udd11\ud83e\udd47\n\n#NFTdrop #NFTGiveaways #NFTGiveaway #NFTs https://t.co/LndvytV7Jf"
#         },
#         {
#             "created_at": "2021-09-25T23:30:55.000Z",
#             "id": "1441908101074980865",
#             "public_metrics": {
#                 "like_count": 1,
#                 "quote_count": 0,
#                 "reply_count": 3,
#                 "retweet_count": 0
#             },
#             "text": "I told people never count my New York Yankees out there's a reason why we have 27 championships because we only do one thing right and that is WIN! BTW BOSTON RED SOX SUCK....\nI'm going to keep posting my cat until we win the World Series. https://t.co/cw3GAt42aZ"
#         },
#         {
#             "created_at": "2021-09-25T23:30:53.000Z",
#             "id": "1441908093630091266",
#             "public_metrics": {
#                 "like_count": 19,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "text": "But also we took the kids and dog for a hike up a mountain (by bike) and only took pictures on the mountain. Like, how we got there didn't seem to be relevant to the adventure at all... https://t.co/IEW7V3PRpK"
#         },
#         {
#             "created_at": "2021-09-25T23:30:52.000Z",
#             "id": "1441908090639577093",
#             "public_metrics": {
#                 "like_count": 17,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "text": "Waiting for food \ud83e\uddb4 \ud83e\uddb4 \ud83e\uddb4 \ud83e\udd73 \ud83e\udd20 \ud83e\udd29  \ud83d\ude18 \n\n#Englishbulldog #dogs #Bulldogs #dogsoftwitter #Puppies #Frenchbulldog #dogsoftwitter #frenchies #pugs #bulldog #bulldogsofinstagram #bulldogs #bulldogpuppy #bulldogfrnces #bulldogingles #frenchbulldog #bulldoglove  #frenchie #dog https://t.co/IZUZ9kYRu5"
#         },
#         {
#             "created_at": "2021-09-25T23:30:52.000Z",
#             "id": "1441908090161532931",
#             "public_metrics": {
#                 "like_count": 1,
#                 "quote_count": 0,
#                 "reply_count": 1,
#                 "retweet_count": 0
#             },
#             "text": "@PrivateerActual What are we doing in America. The cops let the guy go then Dog the Bounty Hunter gets put in the case. The pure absurdity of this https://t.co/hblaVY8gP4"
#         },
#         {
#             "created_at": "2021-09-25T23:30:48.000Z",
#             "id": "1441908072088281090",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "text": "Thigh highs and a cat girl hehsjejbdej https://t.co/HP4BzMxLdk"
#         },
#         {
#             "created_at": "2021-09-25T23:30:47.000Z",
#             "id": "1441908070381076482",
#             "public_metrics": {
#                 "like_count": 2,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "text": "@Juiceman204 Thought y\u2019all was lying about the dog https://t.co/tV6QicO3vt"
#         },
#         {
#             "created_at": "2021-09-25T23:30:47.000Z",
#             "id": "1441908069265465346",
#             "public_metrics": {
#                 "like_count": 1,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "text": "@DoingJack @dprobbob @dejafuuled @katibug817 @lisasmith1150 @Real_Chatty_Cat @SimonJester007 @jvfjr1962 @rhiles2760 @SuzanneLieb4 @JungmanLaura @CharIowa1 @LiberalWarrior_ @ljlevine1 @TheHuniman @air_samurai @77SunnyAndClear @rotterdamvvg @ChasRuth3 @Bedlam_Squatter @brandonbpug @PrezLives2022 @Malcolmdonaghy @Gemini21BLM @omega7stone @azgrl007 @l78lancer @WolfWolfBlue2 @scottronaut @Mary1Kathy @showgirlcf @DrunkenCrunker @gr8shot_keith @PapaJim2u @Sunflwrgirl2 @pax @SmackeyCracks @Eric_shovelhead @BrianHarris33 @MissAngSays @QuinnLeone4 @enespacio @ThemDems @RickResisted @LaurVoted4Biden @GJRboston @Snoesjoe @tanashka2 May the Force be with you Big D \u2b50\ufe0f\u2764\ufe0f\u2764\ufe0f\ud83d\udc95\ud83d\udc95\ud83d\udc3e\ud83d\udc95\ud83d\udc99\ud83d\udc99knock them dead my money is on you \ud83d\udc99\u2b50\ufe0f\ud83d\udc99\ud83d\udc99\u2764\ufe0f\ud83d\udc3e\ud83d\udc95 @dprobbob https://t.co/HJ4RLpjSGv"
#         }
#     ],
#     "meta": {
#         "newest_id": "1441908109593567232",
#         "next_token": "b26v89c19zqg8o3fpds6g2nn58qnzgekw4p6c0ulgqfst",
#         "oldest_id": "1441908069265465346",
#         "result_count": 10
#     }
# }

# %% [markdown]
# Change language to only english :

# %%
url_search = 'https://api.twitter.com/2/tweets/search/recent?query=(cat%20OR%20dog)%20lang%3Aen%20has%3Aimages%20-is%3Aretweet'
response = connect_to_endpoint(url_search, headers, params = parameters)
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# Endpoint Response Code: 200
# {
#     "data": [
#         {
#             "created_at": "2021-09-25T23:30:56.000Z",
#             "id": "1441908105261027329",
#             "public_metrics": {
#                 "like_count": 74,
#                 "quote_count": 1,
#                 "reply_count": 75,
#                 "retweet_count": 74
#             },
#             "text": "\ud83c\udf81Cool Cat giveaway\ud83c\udf81\n\nRules to get rich:\n1\ufe0f\u20e3 Follow Me / \ud83d\udd14\n2\ufe0f\u20e3 Like &amp; RT \u2764\n3\ufe0f\u20e3 Tag more Friends more chances to win \ud83e\udd11\ud83e\udd47\n\n#NFTdrop #NFTGiveaways #NFTGiveaway #NFTs https://t.co/LndvytV7Jf"
#         },
#         {
#             "created_at": "2021-09-25T23:30:55.000Z",
#             "id": "1441908101074980865",
#             "public_metrics": {
#                 "like_count": 1,
#                 "quote_count": 0,
#                 "reply_count": 3,
#                 "retweet_count": 0
#             },
#             "text": "I told people never count my New York Yankees out there's a reason why we have 27 championships because we only do one thing right and that is WIN! BTW BOSTON RED SOX SUCK....\nI'm going to keep posting my cat until we win the World Series. https://t.co/cw3GAt42aZ"
#         },
#         {
#             "created_at": "2021-09-25T23:30:53.000Z",
#             "id": "1441908093630091266",
#             "public_metrics": {
#                 "like_count": 20,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "text": "But also we took the kids and dog for a hike up a mountain (by bike) and only took pictures on the mountain. Like, how we got there didn't seem to be relevant to the adventure at all... https://t.co/IEW7V3PRpK"
#         },
#         {
#             "created_at": "2021-09-25T23:30:52.000Z",
#             "id": "1441908090639577093",
#             "public_metrics": {
#                 "like_count": 17,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "text": "Waiting for food \ud83e\uddb4 \ud83e\uddb4 \ud83e\uddb4 \ud83e\udd73 \ud83e\udd20 \ud83e\udd29  \ud83d\ude18 \n\n#Englishbulldog #dogs #Bulldogs #dogsoftwitter #Puppies #Frenchbulldog #dogsoftwitter #frenchies #pugs #bulldog #bulldogsofinstagram #bulldogs #bulldogpuppy #bulldogfrnces #bulldogingles #frenchbulldog #bulldoglove  #frenchie #dog https://t.co/IZUZ9kYRu5"
#         },
#         {
#             "created_at": "2021-09-25T23:30:52.000Z",
#             "id": "1441908090161532931",
#             "public_metrics": {
#                 "like_count": 1,
#                 "quote_count": 0,
#                 "reply_count": 1,
#                 "retweet_count": 0
#             },
#             "text": "@PrivateerActual What are we doing in America. The cops let the guy go then Dog the Bounty Hunter gets put in the case. The pure absurdity of this https://t.co/hblaVY8gP4"
#         },
#         {
#             "created_at": "2021-09-25T23:30:48.000Z",
#             "id": "1441908072088281090",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "text": "Thigh highs and a cat girl hehsjejbdej https://t.co/HP4BzMxLdk"
#         },
#         {
#             "created_at": "2021-09-25T23:30:47.000Z",
#             "id": "1441908070381076482",
#             "public_metrics": {
#                 "like_count": 2,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "text": "@Juiceman204 Thought y\u2019all was lying about the dog https://t.co/tV6QicO3vt"
#         },
#         {
#             "created_at": "2021-09-25T23:30:47.000Z",
#             "id": "1441908069265465346",
#             "public_metrics": {
#                 "like_count": 1,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "text": "@DoingJack @dprobbob @dejafuuled @katibug817 @lisasmith1150 @Real_Chatty_Cat @SimonJester007 @jvfjr1962 @rhiles2760 @SuzanneLieb4 @JungmanLaura @CharIowa1 @LiberalWarrior_ @ljlevine1 @TheHuniman @air_samurai @77SunnyAndClear @rotterdamvvg @ChasRuth3 @Bedlam_Squatter @brandonbpug @PrezLives2022 @Malcolmdonaghy @Gemini21BLM @omega7stone @azgrl007 @l78lancer @WolfWolfBlue2 @scottronaut @Mary1Kathy @showgirlcf @DrunkenCrunker @gr8shot_keith @PapaJim2u @Sunflwrgirl2 @pax @SmackeyCracks @Eric_shovelhead @BrianHarris33 @MissAngSays @QuinnLeone4 @enespacio @ThemDems @RickResisted @LaurVoted4Biden @GJRboston @Snoesjoe @tanashka2 May the Force be with you Big D \u2b50\ufe0f\u2764\ufe0f\u2764\ufe0f\ud83d\udc95\ud83d\udc95\ud83d\udc3e\ud83d\udc95\ud83d\udc99\ud83d\udc99knock them dead my money is on you \ud83d\udc99\u2b50\ufe0f\ud83d\udc99\ud83d\udc99\u2764\ufe0f\ud83d\udc3e\ud83d\udc95 @dprobbob https://t.co/HJ4RLpjSGv"
#         },
#         {
#             "created_at": "2021-09-25T23:30:39.000Z",
#             "id": "1441908033047732228",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "text": "May or may not have found an island dwelling Cat Goddess, hold my calls https://t.co/jM72cjxwZ4"
#         },
#         {
#             "created_at": "2021-09-25T23:30:35.000Z",
#             "id": "1441908019512545283",
#             "public_metrics": {
#                 "like_count": 1,
#                 "quote_count": 0,
#                 "reply_count": 1,
#                 "retweet_count": 0
#             },
#             "text": "@Author_Gretchen Smart! We only ever had two at a time\u2026except for about 9 months when it was 1 v elderly cat and 2 rescue dogs\u2026. Now, those two dogs. https://t.co/quxTxX81XD"
#         }
#     ],
#     "meta": {
#         "newest_id": "1441908105261027329",
#         "next_token": "b26v89c19zqg8o3fpds6g2nn58qil0vx0h4qbu0c9r6nx",
#         "oldest_id": "1441908019512545283",
#         "result_count": 10
#     }
# }

# %% [markdown]
# ## Try the next_token:

# %%
print(response['data'][-1])
# Out:
# {'text': '@Author_Gretchen Smart! We only ever had two at a time…except for about 9 months when it was 1 v elderly cat and 2 rescue dogs…. Now, those two dogs. https://t.co/quxTxX81XD', 'public_metrics': {'retweet_count': 0, 'reply_count': 1, 'like_count': 1, 'quote_count': 0}, 'id': '1441908019512545283', 'created_at': '2021-09-25T23:30:35.000Z'}

# %%
next_token = response['meta']['next_token']
print(next_token)
# Out:
# b26v89c19zqg8o3fpds6g2nn58qil0vx0h4qbu0c9r6nx

# %%
url_search +='&next_token='+ next_token
response = connect_to_endpoint(url_search, headers, params = parameters)
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# Endpoint Response Code: 200
# {
#     "data": [
#         {
#             "created_at": "2021-09-25T23:30:33.000Z",
#             "id": "1441908010251587585",
#             "public_metrics": {
#                 "like_count": 1,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "text": "Top music. Now playing Catch The Cat - Cherry Laine on https://t.co/9RDEDKWLIS https://t.co/DngQBmVszc"
#         },
#         {
#             "created_at": "2021-09-25T23:30:30.000Z",
#             "id": "1441907998863945735",
#             "public_metrics": {
#                 "like_count": 1,
#                 "quote_count": 0,
#                 "reply_count": 1,
#                 "retweet_count": 0
#             },
#             "text": "@umbiedecoder We don't talk at all so 40% also have dog https://t.co/WUVbNDdbk1"
#         },
#         {
#             "created_at": "2021-09-25T23:30:29.000Z",
#             "id": "1441907993809915907",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "text": "Heya \ud83d\udc14  What a turn of events... 10 hours ago, Daisy the Dog had a drink of the used diaper. I was so angry because it was so innocent! As always, find the rating for this experience on the picture attached. Catcha \ud83d\udc11 https://t.co/KFZmr9Dzrh"
#         },
#         {
#             "created_at": "2021-09-25T23:30:24.000Z",
#             "id": "1441907970061656072",
#             "public_metrics": {
#                 "like_count": 7,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "text": "@ellle_em I have one white cat and a gray cat with a white leg. I like how they blend together in this shot. https://t.co/CE6C6JsW5Q"
#         },
#         {
#             "created_at": "2021-09-25T23:30:12.000Z",
#             "id": "1441907921873510401",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 1,
#                 "retweet_count": 0
#             },
#             "text": "@Fonzaya_ A dog\ud83d\ude02 https://t.co/VPh7LYLIzQ"
#         },
#         {
#             "created_at": "2021-09-25T23:30:09.000Z",
#             "id": "1441907908757889025",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "text": "A dog that visits The Groomin Room is sure to be a happy dog! https://t.co/zt4uLx8GIr"
#         },
#         {
#             "created_at": "2021-09-25T23:30:08.000Z",
#             "id": "1441907904139853830",
#             "public_metrics": {
#                 "like_count": 4,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "text": "So I C  Mrs. Roberta Laundrie can allow her son to go home(Y)from a cross country #vanlife trip w fianc\u00e9 yet he suddenly returns home w/o her yet he\u2019s N fianc\u00e9\u2019s Van no call to police Dog knock on door she calls police #BrianLaundrie #WhereIsBrianLaundrie #justiceforgabbypetito https://t.co/hztaN7ntwA"
#         },
#         {
#             "created_at": "2021-09-25T23:30:08.000Z",
#             "id": "1441907902675972098",
#             "public_metrics": {
#                 "like_count": 3,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "text": "Just a reminder that at 300 followers I will order this Cat Maid dress and wear it when it arrives! https://t.co/tU7nid7nSl"
#         },
#         {
#             "created_at": "2021-09-25T23:30:02.000Z",
#             "id": "1441907881331339269",
#             "public_metrics": {
#                 "like_count": 3,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 1
#             },
#             "text": "How come when it comes to television shows, everyone loves a fixer upper. But, when it's a dog, everyone wants it move in ready?\n\nMajor needs a little work, but he is an absolute angel! \n\nmore: https://t.co/U5eMp1qs9m https://t.co/0FRuiSZQj3"
#         },
#         {
#             "created_at": "2021-09-25T23:30:02.000Z",
#             "id": "1441907878038704128",
#             "public_metrics": {
#                 "like_count": 6,
#                 "quote_count": 1,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "text": "The final 2 hours left for the @simplecatnft x Lucky Crypto Cat collaboration auction! \u23f0 \ud83d\ude3a\n\nhttps://t.co/VkxWaRy68u \n\n#nftart #OpenSeaNFT @opensea #Cryptoart #nftcollectors https://t.co/GXcjWme91t"
#         }
#     ],
#     "meta": {
#         "newest_id": "1441908010251587585",
#         "next_token": "b26v89c19zqg8o3fpds6g2nn3rtqft9dhm2rqcfu4dev1",
#         "oldest_id": "1441907878038704128",
#         "result_count": 10
#     }
# }

# %% [markdown]
# Works! The timestamp printed using the next token is milliseconds earlier than the last one printed in the first batch.
